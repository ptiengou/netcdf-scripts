# %% [markdown]
# # Imports and setting up viz
#
# NB : conda env1 on Mac, lam1env on spirit (Python3.12)

# %%
import numpy as np
import netCDF4 as nc
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler
import cartopy
import cartopy.crs as ccrs
import matplotlib as mpl
from matplotlib.colors import ListedColormap
# %matplotlib inline

# %%
plt.rcParams.update(
        {
            'figure.facecolor': 'white',
            'axes.facecolor': 'white',
            'font.size': 15,
            'figure.dpi': 72.0,
            'xtick.direction': 'in',
            'ytick.direction': 'in',
            'xtick.major.size': 8.0,
            'xtick.minor.size': 4.0,
            'ytick.major.size': 8.0,
            'ytick.minor.size': 4.0,
            'xtick.minor.visible': True,
            'ytick.minor.visible': True,
            'axes.grid': True,
            'axes.titlesize': 'larger',
            'axes.labelsize': 'larger',
            'grid.color': 'dimgray',
            'grid.linestyle': '-',
            'grid.alpha': 0.3,
            'axes.prop_cycle': cycler(
                color=[
                    '#0C5DA5',
                    '#FF9500',
                    '#00B945',
                    '#FF2C00',
                    '#845B97',
                    '#474747',
                    '#9E9E9E',
                ]
            ) * cycler(alpha=[1.0]),
            'scatter.marker': 'x',
            'lines.linewidth': 1.5,
        })

# %%
#define centered colorbar
emb = ListedColormap(mpl.colormaps['RdYlBu_r'](np.linspace(0, 1, 8)))
emb

# %%
#define progressive colorbar
myvir = ListedColormap(mpl.colormaps['viridis'](np.linspace(0, 1, 10)))
myvir

# %%
#define progressive colorbar
reds = ListedColormap(mpl.colormaps['Reds'](np.linspace(0, 1, 10)))
reds

# %% [markdown]
# # Load files
# File to evaluate the behaviour of native routing compared to standard.
#
# First working on the same topographic grid (0.5°).
#
# 4 files are considered : one from the standard routing simulation, three from the native routing simulation (sechiba_history, diag_routing, diag_routing_r)

# %%
# sim_dir='test_sim85'
# sim_dir='tcst7.1'
# simirr_dir='tcst7irr0.6'
sim_dir='../../routing_native/tcst7.1'
simirr_dir='../../routing_native/tcst7irr'
# simirr_06=
gswp3_dir='../../routing_native/tcst7GSWP3'
gswp3irr_dir='../../routing_native/tcst7irrGSWP3'

# %%
#open netcdf files for native routing on ORC grid
# filename = '../sim_outputs/{}/*history.nc'.format(sim_dir)
# natORC = xr.open_mfdataset(filename)
# filename = '../sim_outputs/{}/*history.nc'.format(simirr_dir)
# natORCirr = xr.open_mfdataset(filename)
# natORC

# %%
#open netcdf files for native routing diag_routing_r.nc (on MERIT grid)
# filename = '{}/*diag_routing_r.nc'.format(sim_dir)
# filename = '../routing_native/tcst7_long/*diag_routing_r.nc'
# filename = '../../routing_native/tcst7_long/tcst7_hydrographs_1980-2010.nc'
filename = '../../LAM/sim14/SRF/MO/sim14_hydrographs_monthly_2010-2014.nc'
natDIAG_R0 = xr.open_mfdataset(filename)
# filename = '{}/*diag_routing_r.nc'.format(simirr_dir)
# filename = '../routing_native/tcst7irr_long/*diag_routing_r.nc'
# filename = '../../routing_native/tcst7irr_long/tcst7irr0.9_hydrographs_1980-2010.nc'
# filename = '../../routing_native/tcst7irr0.6_long/tcst7irr0.6_hydrographs_1980-2010.nc'
filename = '../../LAM/sim15/SRF/MO/sim15_hydrographs_monthly_2010-2014.nc'
natDIAG_Rirr0 = xr.open_mfdataset(filename)
# filename = '../../routing_native/tcst7irr0.6_long/tcst7irr0.6_hydrographs_1980-2010.nc'
# natDIAG_Rirr060 = xr.open_mfdataset(filename)
# filename = '{}/*diag_routing_r.nc'.format(gswp3_dir)
# natDIAG_RGSWP30 = xr.open_mfdataset(filename)
# filename = '{}/*diag_routing_r.nc'.format(gswp3irr_dir)
# natDIAG_RGSWP3irr0 = xr.open_mfdataset(filename)
# natDIAG_R0

# %% [markdown]
# # File manipulations

# %%
#rename time_counter to time all files
# natORC = natORC.rename({'time_counter' : 'time'})
# natORCirr = natORCirr.rename({'time_counter' : 'time'})
natDIAG_R = natDIAG_R0.rename({'time_counter' : 'time'})
natDIAG_Rirr = natDIAG_Rirr0.rename({'time_counter' : 'time'})
# natDIAG_Rirr06 = natDIAG_Rirr060.rename({'time_counter' : 'time'})

# natDIAG_RGSWP3 = natDIAG_RGSWP30.rename({'time_counter' : 'time'})
# natDIAG_RGSWP3irr = natDIAG_RGSWP3irr0.rename({'time_counter' : 'time'})

# %%
#Change dataset names attribute for automatic labeling
# natORC.attrs['name'] = 'noirr'
natDIAG_R.attrs['name'] = 'no_irr'
# natORCirr.attrs['name'] = 'irr'
natDIAG_Rirr.attrs['name'] = 'irr'
# natDIAG_Rirr06.attrs['name'] = 'irr_reduced'
# natDIAG_RGSWP3.attrs['name'] = 'GSWP3_no_irr'
# natDIAG_RGSWP3irr.attrs['name'] = 'GSWP3_irr'

# %%
#Rename variables in natDIAG_R_month and natDIAG_R
dict = {
        # 'routing_stream_reservoir_r' : 'streamr',
        # 'routing_fast_reservoir_r' : 'fastr',
        # 'routing_slow_reservoir_r' : 'slowr',
        # 'routing_drainage_r' : 'drainage',
        # 'routing_runoff_r' : 'runoff',
        'routing_hydrographs_r' : 'hydrographs',
        # 'routing_irrigation_r' : 'irrigation',
        # 'irrig_netereq_r' : 'netirrig'
        # 'routing_riverflow_r' : 'riverflow',
        # 'routing_coastalflow_r' : 'coastalflow'
        }
#change the variables that exist according to the dictionary
natDIAG_R = natDIAG_R.rename(dict)
natDIAG_Rirr = natDIAG_Rirr.rename(dict)

# natDIAG_RGSWP3 = natDIAG_RGSWP3.rename(dict)
# natDIAG_RGSWP3irr = natDIAG_RGSWP3irr.rename(dict)
# natDIAG_Rirr06 = natDIAG_Rirr06.rename(dict)

# %%
time = pd.to_datetime(natDIAG_R['time'].values)
shifted_time = time - pd.Timedelta(days=1)
natDIAG_R['time'] = shifted_time

time = pd.to_datetime(natDIAG_Rirr['time'].values)
shifted_time = time - pd.Timedelta(days=1)
natDIAG_Rirr['time'] = shifted_time

# %%
natDIAG_R
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 118, bnds: 2, lon: 1380, lat: 1140)
# Coordinates:
#   * time               (time) datetime64[ns] 2010-02-14 ... 2014-12-31
#   * lon                (lon) float32 -14.99 -14.98 -14.96 ... 7.958 7.975 7.992
#   * lat                (lat) float32 49.99 49.97 49.96 ... 31.04 31.02 31.01
# Dimensions without coordinates: bnds
# Data variables:
#     time_counter_bnds  (time, bnds) datetime64[ns] dask.array<chunksize=(118, 2), meta=np.ndarray>
#     hydrographs        (time, lat, lon) float64 dask.array<chunksize=(118, 1140, 1380), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.3.0 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     name:         no_irr
#     description:  Created by xios
#     title:        Created by xios
#     timeStamp:    2024-Apr-08 21:43:48 GMT
#     uuid:         7ac4927f-907c-41c2-94d7-20501e1a7358
#     history:      Tue Apr 16 00:09:06 2024: ncrcat -O sim14_hydrographs_month...
#     NCO:          netCDF Operators version 5.0.7 (Homepage = http://nco.sf.ne...
#     frequency:    mon
#     CDO:          Climate Data Operators version 2.3.0 (https://mpimet.mpg.de...

# %% [markdown]
# # Stations

# %%
filename='../../../routing/GRDC_Monthly_Jan20_v1_ES.nc'
stations = xr.open_dataset(filename)
stations
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 2580, stations: 1297, maxalt: 2, z: 7740)
# Coordinates:
#   * time               (time) datetime64[ns] 1807-01-15 ... 2021-12-15
# Dimensions without coordinates: stations, maxalt, z
# Data variables: (12/18)
#     number             (stations) int32 ...
#     next               (stations) int32 ...
#     WMOreg             (stations) int32 ...
#     WMOsubreg          (stations) int32 ...
#     name               (stations) |S60 ...
#     river              (stations) |S60 ...
#     ...                 ...
#     altitude           (stations) float32 ...
#     hydrographs        (time, stations) float32 ...
#     alternative_index  (maxalt, stations) int32 ...
#     alt_hydrograph     (time, z) float32 ...
#     flags              (time, stations) float32 ...
#     mergedhydro        (time, stations) float32 ...
# Attributes:
#     history:         Merge of GRDC_Monthly_Jan20.nc and Spain_Monthly_May20.nc
#     metadata:        Missing metadata are replaced by XXX or -999
#     Source:          GRDC_Monthly_Jan20.nc+Spain_Monthly_May20.nc
#     MergeSource1:    Computed at GRDC from daily values
#     MergeSource2:    Spanish data obtained from Observatorio del Ebro in May ...
#     MergeSource3:    Original monthly Hydrographs
#     ConversionDate:  2020-05-08

# %%
# extract subset of stations file where country contains ES
# mask = (stations['country']==b'ES')
# stations_ES = stations.sel(stations=mask)
# stations_ES

# %%
# print stations_ES to netcdf
# stations_ES.to_netcdf('../obs/GRDC_Monthly_Jan20_v1_ES.nc')

# %%
# load csv file 
filename = '../../../routing/GRDC_stations_MERIT_ES.csv'
csv_file = pd.read_csv(filename)
# csv_file

# %%
# create dir with station id as key and name, river, lat_grid, lon_grid
stations_merit_csv = {}
for index, row in csv_file.iterrows():
    stations_merit_csv[row['number']] = {'name': row['name'], 'river': row['river'], 'lat_grid': row['Lat_Grid'], 'lon_grid': row['Lon_Grid'], 'last_record': row['LastRecord']}
stations_merit_csv
# Out:
# {6212700: {'name': 'Peral De Arlanza',
#   'river': 'Arlanza, Rio',
#   'lat_grid': 42.07500076293945,
#   'lon_grid': -4.074992656707764,
#   'last_record': '1984-08-15'},
#  6217700: {'name': 'Pinos Puente',
#   'river': 'Frailes, Rio',
#   'lat_grid': 37.27499771118164,
#   'lon_grid': -3.758326292037964,
#   'last_record': '1984-08-15'},
#  6227800: {'name': 'Martorell',
#   'river': 'Llobregat, Rio',
#   'lat_grid': 41.47499847412109,
#   'lon_grid': 1.9416741132736208,
#   'last_record': '1984-08-15'},
#  6217110: {'name': 'Cantillana',
#   'river': 'Guadalquivir, Rio',
#   'lat_grid': 37.59166717529297,
#   'lon_grid': -5.824993133544922,
#   'last_record': '1992-11-15'},
#  6227810: {'name': 'Sant Joan Despi',
#   'river': 'Llobregat, Rio',
#   'lat_grid': 41.35833358764648,
#   'lon_grid': 2.0416741371154785,
#   'last_record': '1989-11-15'},
#  6227850: {'name': 'Sifon N.A.',
#   'river': 'Besos, Rio',
#   'lat_grid': 41.44166564941406,
#   'lon_grid': 2.208340883255005,
#   'last_record': '1989-11-15'},
#  6227100: {'name': 'Bobadilla',
#   'river': 'Guadalhorce, Rio',
#   'lat_grid': 37.04166412353516,
#   'lon_grid': -4.70832633972168,
#   'last_record': '1984-08-15'},
#  6217120: {'name': 'Sevilla',
#   'river': 'Guadalquivir, Rio',
#   'lat_grid': 37.39166641235352,
#   'lon_grid': -6.008326530456543,
#   'last_record': '1964-11-15'},
#  6227900: {'name': 'Roda De Ter',
#   'river': 'Ter, Rio',
#   'lat_grid': 41.97499847412109,
#   'lon_grid': 2.325007438659668,
#   'last_record': '1984-08-15'},
#  6227300: {'name': 'El Chono',
#   'river': 'Nacimiento, Rio',
#   'lat_grid': 37.07500076293945,
#   'lon_grid': -2.6416594982147217,
#   'last_record': '1984-08-15'},
#  6217130: {'name': 'La Presa',
#   'river': 'Guadalquivir, Rio',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1990-11-15'},
#  6217600: {'name': 'El Doctor',
#   'river': 'Guardal, Rio',
#   'lat_grid': 37.85833358764648,
#   'lon_grid': -4.691659450531006,
#   'last_record': '1984-08-15'},
#  6298000: {'name': 'Lietor',
#   'river': ' Segura',
#   'lat_grid': 38.508331298828125,
#   'lon_grid': -1.858326077461243,
#   'last_record': '1949-09-15'},
#  6298001: {'name': 'Canaveruelas',
#   'river': 'Guadiela',
#   'lat_grid': 40.44166564941406,
#   'lon_grid': -2.624992847442627,
#   'last_record': '1914-11-15'},
#  6298002: {'name': 'Cabreros Del Rio',
#   'river': 'Esla',
#   'lat_grid': 42.39166641235352,
#   'lon_grid': -5.558326244354248,
#   'last_record': '2013-09-15'},
#  6298003: {'name': 'Luciana',
#   'river': 'Bullaque',
#   'lat_grid': 38.99166488647461,
#   'lon_grid': -4.274992942810059,
#   'last_record': '2012-09-15'},
#  6298004: {'name': 'Alcaine',
#   'river': 'Martin',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298005: {'name': 'Escalona',
#   'river': 'Alberche',
#   'lat_grid': 40.15833282470703,
#   'lon_grid': -4.408326148986816,
#   'last_record': '2013-05-15'},
#  6298006: {'name': 'Ejea De Los Caballeros',
#   'river': 'Arba De Luesia',
#   'lat_grid': 42.125,
#   'lon_grid': -1.1583260297775269,
#   'last_record': '2013-09-15'},
#  6298007: {'name': 'Ateca',
#   'river': 'Jalon',
#   'lat_grid': 41.32500076293945,
#   'lon_grid': -1.8083261251449585,
#   'last_record': '2013-09-15'},
#  6298008: {'name': 'Viacamp Y Litera',
#   'river': 'Noguera Ribagorzana',
#   'lat_grid': 42.02499771118164,
#   'lon_grid': 0.6583406925201416,
#   'last_record': '1958-11-15'},
#  6298009: {'name': 'Marmolejo',
#   'river': 'Guadalquivir',
#   'lat_grid': 38.05833435058594,
#   'lon_grid': -4.17499303817749,
#   'last_record': '1994-09-15'},
#  6298010: {'name': 'Huerto',
#   'river': 'Alcanadre',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298011: {'name': 'Negreira',
#   'river': 'Barcala',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298012: {'name': 'Tineo',
#   'river': 'Narcea',
#   'lat_grid': 43.29166793823242,
#   'lon_grid': -6.42499303817749,
#   'last_record': '1929-09-15'},
#  6298013: {'name': 'Cabanes De Esgueva',
#   'river': 'Esgueva',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298014: {'name': 'Valdes',
#   'river': 'Esva O Naraval',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298015: {'name': 'Franco. El',
#   'river': 'Porcia',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298016: {'name': 'Puente De Domingo Florez',
#   'river': 'Sil',
#   'lat_grid': 42.42499923706055,
#   'lon_grid': -6.808326244354248,
#   'last_record': '1959-09-15'},
#  6298017: {'name': 'Cehegin',
#   'river': ' Segura',
#   'lat_grid': 38.17499923706055,
#   'lon_grid': -1.74165940284729,
#   'last_record': '1947-09-15'},
#  6298018: {'name': 'Neda',
#   'river': 'Belelle',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298019: {'name': 'Lietor',
#   'river': 'Mundo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2009-09-15'},
#  6298020: {'name': 'Pedrosa Del Principe',
#   'river': 'Odra',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298021: {'name': 'Simancas',
#   'river': 'Pisuerga',
#   'lat_grid': 41.59166717529297,
#   'lon_grid': -4.824993133544922,
#   'last_record': '1919-10-15'},
#  6298022: {'name': 'Mandayona',
#   'river': 'Dulce',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298023: {'name': 'Puebla De Castro. La',
#   'river': 'Esera',
#   'lat_grid': 42.125,
#   'lon_grid': 0.3083406984806061,
#   'last_record': '1972-09-15'},
#  6298024: {'name': 'Vegas De Matute',
#   'river': 'Moros',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298025: {'name': 'Leon',
#   'river': 'Bernesga',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298026: {'name': 'Navarres',
#   'river': ' Jucar',
#   'lat_grid': 39.125,
#   'lon_grid': -0.6916593313217163,
#   'last_record': '1967-09-15'},
#  6298027: {'name': 'Villora',
#   'river': 'Cabriel',
#   'lat_grid': 39.74166488647461,
#   'lon_grid': -1.641659379005432,
#   'last_record': '2013-09-15'},
#  6298028: {'name': 'Almodovar Del Rio',
#   'river': 'Guadalquivir',
#   'lat_grid': 37.80833435058594,
#   'lon_grid': -5.024992942810059,
#   'last_record': '1978-09-15'},
#  6298029: {'name': 'Leiro',
#   'river': ' Mino-Sil',
#   'lat_grid': 42.39166641235352,
#   'lon_grid': -8.191659927368164,
#   'last_record': '1972-09-15'},
#  6298030: {'name': 'Bonar',
#   'river': ' Duero',
#   'lat_grid': 42.92499923706055,
#   'lon_grid': -5.291659355163574,
#   'last_record': '2013-09-15'},
#  6298031: {'name': 'Rabanos. Los',
#   'river': 'Duero',
#   'lat_grid': 41.67499923706055,
#   'lon_grid': -2.3916594982147217,
#   'last_record': '2013-09-15'},
#  6298032: {'name': 'Talayuela',
#   'river': 'Alcanizo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298033: {'name': 'Sietamo',
#   'river': 'Guatizalema',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298034: {'name': 'Madridejos',
#   'river': 'Amarguillo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1930-11-15'},
#  6298035: {'name': 'Camarenilla',
#   'river': 'Vallehermoso',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298036: {'name': 'Guardamar Del Segura',
#   'river': 'Segura',
#   'lat_grid': 38.09166717529297,
#   'lon_grid': -0.6583260297775269,
#   'last_record': '2013-09-15'},
#  6298037: {'name': 'Tauste',
#   'river': 'Arba De Luesia',
#   'lat_grid': 41.90833282470703,
#   'lon_grid': -1.2749927043914795,
#   'last_record': '2013-09-15'},
#  6298038: {'name': 'Ponteareas',
#   'river': 'Tea',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298039: {'name': 'Olaibar',
#   'river': 'Ulzama',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298040: {'name': 'Oiartzun',
#   'river': 'Oyarzun',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2007-09-15'},
#  6298041: {'name': 'Montanuy',
#   'river': 'Noguera Ribagorzana',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1997-09-15'},
#  6298042: {'name': 'Castril',
#   'river': ' Guadalquivir',
#   'lat_grid': 37.80833435058594,
#   'lon_grid': -2.791659355163574,
#   'last_record': '1991-09-15'},
#  6298043: {'name': 'Cofrentes',
#   'river': 'Cabriel',
#   'lat_grid': 39.258331298828125,
#   'lon_grid': -1.091659426689148,
#   'last_record': '2013-09-15'},
#  6298044: {'name': 'Gallur',
#   'river': 'Arba De Luesia',
#   'lat_grid': 41.89166641235352,
#   'lon_grid': -1.2916593551635742,
#   'last_record': '2013-09-15'},
#  6298045: {'name': 'Pontenova. A',
#   'river': 'Eo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2009-09-15'},
#  6298046: {'name': 'Devanos',
#   'river': 'Anamaza',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2010-09-15'},
#  6298047: {'name': 'Zamora',
#   'river': 'Duero',
#   'lat_grid': 41.508331298828125,
#   'lon_grid': -5.724992752075195,
#   'last_record': '2013-09-15'},
#  6298048: {'name': 'Naut Aran',
#   'river': 'Valarties',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1991-09-15'},
#  6298049: {'name': 'Alcala De Henares',
#   'river': 'Henares',
#   'lat_grid': 40.45833206176758,
#   'lon_grid': -3.424992799758911,
#   'last_record': '2013-09-15'},
#  6298050: {'name': 'Fresno Alhandiga',
#   'river': 'Alhandiga',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298051: {'name': 'Valdelugueros',
#   'river': 'Curueno',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298052: {'name': 'Porto',
#   'river': 'Bibey',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298053: {'name': 'Provencio. El',
#   'river': 'Zancara',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1974-09-15'},
#  6298054: {'name': 'Morales De Rey',
#   'river': 'Eria',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298055: {'name': 'Villanueva De Los Infantes',
#   'river': 'Esgueva',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298056: {'name': 'Brion',
#   'river': 'Sar',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298057: {'name': 'Ortigueira',
#   'river': 'Mera',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298058: {'name': 'Cordobilla De Lacara',
#   'river': ' Guadiana',
#   'lat_grid': 39.15833282470703,
#   'lon_grid': -6.42499303817749,
#   'last_record': '1994-09-15'},
#  6298059: {'name': 'Casas-Ibanez',
#   'river': 'Cabriel',
#   'lat_grid': 39.35833358764648,
#   'lon_grid': -1.4416593313217163,
#   'last_record': '1965-09-15'},
#  6298060: {'name': 'Vilches',
#   'river': ' Guadalquivir',
#   'lat_grid': 38.15833282470703,
#   'lon_grid': -3.474992752075196,
#   'last_record': '2012-09-15'},
#  6298061: {'name': 'Villasequilla',
#   'river': 'Martin Roman',
#   'lat_grid': 39.875,
#   'lon_grid': -3.7249927520751953,
#   'last_record': '2013-09-15'},
#  6298062: {'name': 'Atazar. El',
#   'river': ' Tajo',
#   'lat_grid': 40.90833282470703,
#   'lon_grid': -3.474992752075196,
#   'last_record': '1986-09-15'},
#  6298063: {'name': 'Villar Del Rey',
#   'river': ' Guadiana',
#   'lat_grid': 39.15833282470703,
#   'lon_grid': -6.858326435089111,
#   'last_record': '2009-09-15'},
#  6298064: {'name': 'Albentosa',
#   'river': 'Albentosa',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1976-09-15'},
#  6298065: {'name': 'Rionegro Del Puente',
#   'river': 'Negro',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298066: {'name': 'Colomera',
#   'river': ' Guadalquivir',
#   'lat_grid': 37.40833282470703,
#   'lon_grid': -3.7249927520751953,
#   'last_record': '2013-09-15'},
#  6298067: {'name': 'Oroso',
#   'river': 'Tambre',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298068: {'name': 'Villanueva De Cameros',
#   'river': 'Albercos',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298069: {'name': 'Nogueira De Ramuin',
#   'river': ' Mino-Sil',
#   'lat_grid': 42.40833282470703,
#   'lon_grid': -7.641659736633301,
#   'last_record': '1993-09-15'},
#  6298070: {'name': 'Andujar',
#   'river': ' Guadalquivir',
#   'lat_grid': 38.15833282470703,
#   'lon_grid': -3.991659641265869,
#   'last_record': '1995-09-15'},
#  6298071: {'name': 'Constantina',
#   'river': ' Guadalquivir',
#   'lat_grid': 37.77499771118164,
#   'lon_grid': -5.691659450531006,
#   'last_record': '2013-09-15'},
#  6298072: {'name': 'San Esteban De Gormaz',
#   'river': 'Duero',
#   'lat_grid': 41.57500076293945,
#   'lon_grid': -3.2083261013031006,
#   'last_record': '1991-09-15'},
#  6298073: {'name': 'Penamellera Alta',
#   'river': 'Cares',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298074: {'name': 'Cofrentes',
#   'river': 'Jucar',
#   'lat_grid': 39.22499847412109,
#   'lon_grid': -1.058326005935669,
#   'last_record': '1951-09-15'},
#  6298075: {'name': 'Erla',
#   'river': 'Arba De Biel',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298076: {'name': 'Soutomaior',
#   'river': 'Oitaven',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298077: {'name': 'Mirandilla',
#   'river': 'Aljucen',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298078: {'name': 'Alins',
#   'river': 'Tor',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298079: {'name': 'Villaquejida',
#   'river': 'Esla',
#   'lat_grid': 42.125,
#   'lon_grid': -5.574993133544922,
#   'last_record': '1969-09-15'},
#  6298080: {'name': 'Biota',
#   'river': 'Arba De Luesia',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298081: {'name': 'Cenicero',
#   'river': 'Najerilla',
#   'lat_grid': 42.49166488647461,
#   'lon_grid': -2.691659450531006,
#   'last_record': '2013-09-15'},
#  6298082: {'name': 'Balaguer',
#   'river': 'Segre',
#   'lat_grid': 41.79166793823242,
#   'lon_grid': 0.8083407282829285,
#   'last_record': '2013-09-15'},
#  6298083: {'name': 'Carrascosa',
#   'river': ' Tajo',
#   'lat_grid': 40.55833435058594,
#   'lon_grid': -2.174992799758911,
#   'last_record': '1986-09-15'},
#  6298084: {'name': 'Lozoya',
#   'river': ' Tajo',
#   'lat_grid': 40.94166564941406,
#   'lon_grid': -3.7749929428100586,
#   'last_record': '1986-09-15'},
#  6298085: {'name': 'Aguilar De La Frontera',
#   'river': 'Cabra',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298086: {'name': 'Beceite',
#   'river': 'Pena',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298087: {'name': 'Freila',
#   'river': ' Guadalquivir',
#   'lat_grid': 37.55833435058594,
#   'lon_grid': -2.9583261013031006,
#   'last_record': '2009-09-15'},
#  6298088: {'name': 'Toga',
#   'river': 'Mijares',
#   'lat_grid': 40.04166793823242,
#   'lon_grid': -0.3583259880542755,
#   'last_record': '1957-09-15'},
#  6298089: {'name': 'Campo Lameiro',
#   'river': 'Lerez',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1998-09-15'},
#  6298090: {'name': 'Viso Del Marques',
#   'river': ' Guadalquivir',
#   'lat_grid': 38.60833358764648,
#   'lon_grid': -3.674992799758911,
#   'last_record': '1967-09-15'},
#  6298091: {'name': 'Sotoserrano',
#   'river': 'Cuerpo De Hombre',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298092: {'name': 'Loja',
#   'river': 'Frio',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2008-09-15'},
#  6298093: {'name': 'Calamocha',
#   'river': 'Jiloca',
#   'lat_grid': 40.92499923706055,
#   'lon_grid': -1.308326005935669,
#   'last_record': '2013-09-15'},
#  6298094: {'name': 'Torno. El',
#   'river': 'Jerte',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298095: {'name': 'Hellin',
#   'river': 'Minateda',
#   'lat_grid': 38.40833282470703,
#   'lon_grid': -1.641659379005432,
#   'last_record': '1992-09-15'},
#  6298096: {'name': 'Librilla',
#   'river': 'Algeciras',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1992-09-15'},
#  6298097: {'name': 'Vinuesa',
#   'river': 'Duero',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1918-11-15'},
#  6298098: {'name': 'Cebrones Del Rio',
#   'river': 'Orbigo',
#   'lat_grid': 42.24166488647461,
#   'lon_grid': -5.824993133544922,
#   'last_record': '2013-09-15'},
#  6298099: {'name': 'Madarcos',
#   'river': 'Nava. La',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298100: {'name': 'Navajas',
#   'river': 'Palancia',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298101: {'name': 'Pontes De Garcia Rodriguez. As',
#   'river': 'Eume',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1958-09-15'},
#  6298102: {'name': 'Murcia',
#   'river': 'Guadalentin',
#   'lat_grid': 37.92499923706055,
#   'lon_grid': -1.224992752075195,
#   'last_record': '1944-11-15'},
#  6298103: {'name': 'Cillaperlata',
#   'river': 'Ebro',
#   'lat_grid': 42.79166793823242,
#   'lon_grid': -3.341659545898437,
#   'last_record': '2013-09-15'},
#  6298104: {'name': 'Cofrentes',
#   'river': ' Jucar',
#   'lat_grid': 39.24166488647461,
#   'lon_grid': -1.0416593551635742,
#   'last_record': '1984-09-15'},
#  6298105: {'name': 'Navacerrada',
#   'river': ' Tajo',
#   'lat_grid': 40.70833206176758,
#   'lon_grid': -4.008326053619385,
#   'last_record': '1986-09-15'},
#  6298106: {'name': 'Adamuz',
#   'river': ' Guadalquivir',
#   'lat_grid': 38.04166412353516,
#   'lon_grid': -4.67499303817749,
#   'last_record': '1995-09-15'},
#  6298107: {'name': 'Arcos De Jalon',
#   'river': 'Blanco',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298108: {'name': 'Bolo. O',
#   'river': 'Bibey',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1993-09-15'},
#  6298109: {'name': 'Villalonga',
#   'river': 'Serpis',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298110: {'name': 'Bejar',
#   'river': 'Cuerpo De Hombre',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298111: {'name': 'Pobla De Benifassa. La',
#   'river': 'Corruscas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1976-09-15'},
#  6298112: {'name': 'Puigcerda',
#   'river': 'Carol O Arabo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298113: {'name': 'Benageber',
#   'river': 'Turia O Guadalaviar',
#   'lat_grid': 39.72499847412109,
#   'lon_grid': -1.091659426689148,
#   'last_record': '1965-09-15'},
#  6298114: {'name': 'Panton',
#   'river': ' Mino-Sil',
#   'lat_grid': 42.45833206176758,
#   'lon_grid': -7.7249932289123535,
#   'last_record': '1960-09-15'},
#  6298115: {'name': 'Ibias',
#   'river': 'Ibias',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298116: {'name': 'Baena',
#   'river': ' Guadalquivir',
#   'lat_grid': 37.64166641235352,
#   'lon_grid': -4.224992752075195,
#   'last_record': '1994-09-15'},
#  6298117: {'name': 'Ribadeo',
#   'river': 'Grande Ribadeo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298118: {'name': 'Puebla De Lillo',
#   'river': 'Porma',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298119: {'name': 'Porzuna',
#   'river': 'Bullaque',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298120: {'name': 'Canal De Berdun',
#   'river': 'Aragon',
#   'lat_grid': 42.59166717529297,
#   'lon_grid': -0.8749926686286926,
#   'last_record': '2013-09-15'},
#  6298121: {'name': 'Mula',
#   'river': 'Perea',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1971-09-15'},
#  6298122: {'name': 'Lorca',
#   'river': 'Luchena O Del Alcaide',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1971-09-15'},
#  6298123: {'name': 'Jaen',
#   'river': 'Quiebrajano O Jaen',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298124: {'name': 'Peralta De Calasanz',
#   'river': 'Sosa',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298125: {'name': 'Feria',
#   'river': 'Guadajira',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1968-09-15'},
#  6298126: {'name': 'Vitoria-Gasteiz',
#   'river': 'Alegria',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1980-09-15'},
#  6298127: {'name': 'Arandiga',
#   'river': 'Jalon',
#   'lat_grid': 41.49166488647461,
#   'lon_grid': -1.4583261013031006,
#   'last_record': '2013-09-15'},
#  6298128: {'name': 'Orihuela',
#   'river': ' Segura',
#   'lat_grid': 38.02499771118164,
#   'lon_grid': -0.8749926686286926,
#   'last_record': '1947-09-15'},
#  6298129: {'name': 'Arrazua-Ubarrundia',
#   'river': 'Zadorra',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1955-09-15'},
#  6298130: {'name': 'Consuegra',
#   'river': 'Amarguillo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298131: {'name': 'Montanejos',
#   'river': ' Jucar',
#   'lat_grid': 40.09166717529297,
#   'lon_grid': -0.5416593551635742,
#   'last_record': '2013-09-15'},
#  6298132: {'name': 'Tous',
#   'river': 'Cazunta O Escalona',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1931-11-15'},
#  6298133: {'name': 'Cervera De Pisuerga',
#   'river': ' Duero',
#   'lat_grid': 42.90833282470703,
#   'lon_grid': -4.524992942810059,
#   'last_record': '2013-09-15'},
#  6298134: {'name': 'Zamarra',
#   'river': ' Duero',
#   'lat_grid': 40.52499771118164,
#   'lon_grid': -6.474992752075195,
#   'last_record': '1967-09-15'},
#  6298135: {'name': 'Cacabelos',
#   'river': 'Cua',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1963-09-15'},
#  6298136: {'name': 'Ribadumia',
#   'river': 'Umia',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298137: {'name': 'Onda',
#   'river': ' Jucar',
#   'lat_grid': 40.008331298828125,
#   'lon_grid': -0.2249926626682281,
#   'last_record': '1974-04-15'},
#  6298138: {'name': 'Zaragoza',
#   'river': 'Gallego',
#   'lat_grid': 41.67499923706055,
#   'lon_grid': -0.8416593670845032,
#   'last_record': '2007-08-15'},
#  6298139: {'name': 'Lugo',
#   'river': 'Mino',
#   'lat_grid': 43.02499771118164,
#   'lon_grid': -7.591659545898437,
#   'last_record': '2013-09-15'},
#  6298140: {'name': 'Cambre',
#   'river': 'Mero',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1987-09-15'},
#  6298141: {'name': 'Monroyo',
#   'river': 'Tastavins',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2009-09-15'},
#  6298142: {'name': 'Segovia',
#   'river': 'Eresma',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298143: {'name': 'Villamanan',
#   'river': 'Esla',
#   'lat_grid': 42.375,
#   'lon_grid': -5.558326244354248,
#   'last_record': '1998-09-15'},
#  6298144: {'name': 'Sesena',
#   'river': 'Tajo',
#   'lat_grid': 40.02499771118164,
#   'lon_grid': -3.658326148986816,
#   'last_record': '1931-11-15'},
#  6298145: {'name': 'Daimiel',
#   'river': 'Guadiana',
#   'lat_grid': 39.10833358764648,
#   'lon_grid': -3.758326292037964,
#   'last_record': '1984-07-15'},
#  6298146: {'name': 'Manzanares El Real',
#   'river': 'Manzanares',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298147: {'name': 'Navascues/Nabaskoze',
#   'river': 'Salazar',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298148: {'name': 'Guadarrama',
#   'river': ' Tajo',
#   'lat_grid': 40.65833282470703,
#   'lon_grid': -4.124992847442627,
#   'last_record': '1986-09-15'},
#  6298149: {'name': 'Lucena',
#   'river': ' Guadalquivir',
#   'lat_grid': 37.29166412353516,
#   'lon_grid': -4.67499303817749,
#   'last_record': '2009-04-15'},
#  6298150: {'name': 'Buitrago Del Lozoya',
#   'river': ' Tajo',
#   'lat_grid': 40.99166488647461,
#   'lon_grid': -3.6416594982147217,
#   'last_record': '1986-09-15'},
#  6298151: {'name': 'Tui',
#   'river': 'Louro',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298152: {'name': 'Tibi',
#   'river': 'Monegre',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1995-09-15'},
#  6298153: {'name': 'Jerez Del Marquesado',
#   'river': 'Guadix',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1931-11-15'},
#  6298154: {'name': 'Longuida/Longida',
#   'river': 'Irati',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298155: {'name': 'Guillena',
#   'river': 'Huelva',
#   'lat_grid': 37.67499923706055,
#   'lon_grid': -6.124992847442627,
#   'last_record': '2013-09-15'},
#  6298156: {'name': 'Ampuero',
#   'river': 'Ason',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298157: {'name': 'Lupinen-Ortilla',
#   'river': 'Soton',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298158: {'name': 'Moraleda De Zafayona',
#   'river': 'Genil',
#   'lat_grid': 37.20833206176758,
#   'lon_grid': -3.941659450531006,
#   'last_record': '2009-09-15'},
#  6298159: {'name': 'Acebo',
#   'river': 'Cervigona',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298160: {'name': 'Toril',
#   'river': 'Tajo',
#   'lat_grid': 39.84166717529297,
#   'lon_grid': -6.058326244354248,
#   'last_record': '1950-09-15'},
#  6298161: {'name': 'Monforte De Lemos',
#   'river': 'Cabe',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298162: {'name': 'Abaran',
#   'river': 'Moro (Raja. La)',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1931-09-15'},
#  6298163: {'name': 'Aoiz/Agoitz',
#   'river': 'Irati',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298164: {'name': 'Dehesas De Guadix',
#   'river': 'Fardes',
#   'lat_grid': 37.54166412353516,
#   'lon_grid': -3.108326196670532,
#   'last_record': '2012-09-15'},
#  6298165: {'name': 'Puebla De Don Rodrigo',
#   'river': 'Guadiana',
#   'lat_grid': 39.10833358764648,
#   'lon_grid': -4.5916595458984375,
#   'last_record': '2012-09-15'},
#  6298166: {'name': 'Venturada',
#   'river': 'Albala',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298167: {'name': 'Medellin',
#   'river': 'Guadiana',
#   'lat_grid': 38.97499847412109,
#   'lon_grid': -5.95832633972168,
#   'last_record': '1918-05-15'},
#  6298168: {'name': 'Parres',
#   'river': 'Pilona',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298169: {'name': 'Hornachos',
#   'river': ' Guadiana',
#   'lat_grid': 38.52499771118164,
#   'lon_grid': -6.124992847442627,
#   'last_record': '1931-11-15'},
#  6298170: {'name': 'Fuentiduena',
#   'river': 'Duraton',
#   'lat_grid': 41.44166564941406,
#   'lon_grid': -3.9749927520751953,
#   'last_record': '2013-09-15'},
#  6298171: {'name': 'Carballo',
#   'river': 'Allones',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298172: {'name': 'Priego',
#   'river': 'Escabas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298173: {'name': 'Villargordo Del Cabriel',
#   'river': 'Cabriel',
#   'lat_grid': 39.52499771118164,
#   'lon_grid': -1.5083260536193848,
#   'last_record': '2013-09-15'},
#  6298174: {'name': 'Os De Balaguer',
#   'river': 'Noguera Ribagorzana',
#   'lat_grid': 41.97499847412109,
#   'lon_grid': 0.6083407402038574,
#   'last_record': '1958-11-15'},
#  6298175: {'name': 'Madrid',
#   'river': 'Manzanares',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2011-05-15'},
#  6298176: {'name': 'Torre Del Burgo',
#   'river': 'Badiel',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298177: {'name': 'Orihuela',
#   'river': 'Segura',
#   'lat_grid': 38.07500076293945,
#   'lon_grid': -0.9583260416984558,
#   'last_record': '2013-09-15'},
#  6298178: {'name': 'Betanzos',
#   'river': 'Mero',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298179: {'name': 'Valencia De Alcantara',
#   'river': 'Alburrel',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298180: {'name': 'Toreno',
#   'river': 'Sil',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1967-09-15'},
#  6298181: {'name': 'Canfranc',
#   'river': 'Aragon',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298182: {'name': 'Vall De Boi. La',
#   'river': 'San Nicolas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1997-09-15'},
#  6298183: {'name': 'Garrovilla. La',
#   'river': 'Lacara',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298184: {'name': 'Valverde De Jucar',
#   'river': 'Gritos',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1952-09-15'},
#  6298185: {'name': 'Aznalcazar',
#   'river': 'Ciguena',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2009-09-15'},
#  6298186: {'name': 'Ona',
#   'river': 'Oca',
#   'lat_grid': 42.74166488647461,
#   'lon_grid': -3.4083261489868164,
#   'last_record': '2013-09-15'},
#  6298187: {'name': 'Madrid',
#   'river': ' Tajo',
#   'lat_grid': 40.54166793823242,
#   'lon_grid': -3.791659593582153,
#   'last_record': '1986-09-15'},
#  6298188: {'name': 'Puebla De Guzman',
#   'river': 'Cobica',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2004-05-15'},
#  6298189: {'name': 'Lumbreras',
#   'river': 'Piqueras - Lumbreras',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298190: {'name': 'Grado. El',
#   'river': 'Cinca',
#   'lat_grid': 42.05833435058594,
#   'lon_grid': 0.2083407044410705,
#   'last_record': '2013-09-15'},
#  6298191: {'name': 'Aljucen',
#   'river': 'Aljucen',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298192: {'name': 'Ojos',
#   'river': 'Segura',
#   'lat_grid': 38.14166641235352,
#   'lon_grid': -1.341659426689148,
#   'last_record': '2013-09-15'},
#  6298193: {'name': 'Don Benito',
#   'river': 'Guadiana',
#   'lat_grid': 39.02499771118164,
#   'lon_grid': -5.824993133544922,
#   'last_record': '2012-08-15'},
#  6298194: {'name': 'Alia',
#   'river': 'Estena',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1931-11-15'},
#  6298195: {'name': 'Camarinas',
#   'river': 'Grande',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298196: {'name': 'Cieza',
#   'river': 'Segura',
#   'lat_grid': 38.22499847412109,
#   'lon_grid': -1.4083260297775269,
#   'last_record': '2013-09-15'},
#  6298197: {'name': 'Puebla De Arenoso',
#   'river': 'Mijares',
#   'lat_grid': 40.10833358764648,
#   'lon_grid': -0.6083260178565979,
#   'last_record': '2013-09-15'},
#  6298198: {'name': 'Merida',
#   'river': ' Guadiana',
#   'lat_grid': 38.92499923706055,
#   'lon_grid': -6.42499303817749,
#   'last_record': '1931-11-15'},
#  6298199: {'name': 'Oropesa',
#   'river': ' Tajo',
#   'lat_grid': 40.10833358764648,
#   'lon_grid': -5.324993133544922,
#   'last_record': '1986-09-15'},
#  6298200: {'name': 'Cordoba',
#   'river': ' Guadalquivir',
#   'lat_grid': 38.02499771118164,
#   'lon_grid': -4.791659355163574,
#   'last_record': '1962-09-15'},
#  6298201: {'name': 'Barrios De Luna. Los',
#   'river': 'Luna',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298202: {'name': 'Santibanez De La Sierra',
#   'river': 'Alagon',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298203: {'name': 'Berriatua',
#   'river': 'Artibay',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2007-04-15'},
#  6298204: {'name': 'Velilla Del Rio Carrion',
#   'river': 'Besandino',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298205: {'name': 'Barboles',
#   'river': 'Jalon',
#   'lat_grid': 41.72499847412109,
#   'lon_grid': -1.1749926805496216,
#   'last_record': '2013-09-15'},
#  6298206: {'name': 'Andosilla',
#   'river': 'Ega I',
#   'lat_grid': 42.375,
#   'lon_grid': -1.9416594505310056,
#   'last_record': '2013-09-15'},
#  6298207: {'name': 'Logrosan',
#   'river': 'Ruecas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298208: {'name': 'Padrenda',
#   'river': 'Barjas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298209: {'name': 'Lastras De Cuellar',
#   'river': 'Cega',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298210: {'name': 'Sarria',
#   'river': 'Sarria',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2009-06-15'},
#  6298211: {'name': 'Alange',
#   'river': ' Guadiana',
#   'lat_grid': 38.79166412353516,
#   'lon_grid': -6.274992942810059,
#   'last_record': '1976-11-15'},
#  6298212: {'name': 'Ubeda',
#   'river': ' Guadalquivir',
#   'lat_grid': 37.92499923706055,
#   'lon_grid': -3.308326244354248,
#   'last_record': '1994-09-15'},
#  6298213: {'name': 'Villafranca Del Bierzo',
#   'river': 'Cua',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298214: {'name': 'Riaza',
#   'river': 'Riaza',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298215: {'name': 'Vegas Del Condado',
#   'river': 'Porma',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298216: {'name': 'Retuerta Del Bullaque',
#   'river': 'Bullaque',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1974-09-15'},
#  6298217: {'name': 'Pueblanueva. La',
#   'river': 'Sangreras',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298218: {'name': 'Guillena',
#   'river': 'Cala',
#   'lat_grid': 37.67499923706055,
#   'lon_grid': -6.141659736633301,
#   'last_record': '1994-09-15'},
#  6298219: {'name': 'Cervera De Pisuerga',
#   'river': 'Pisuerga',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1995-09-15'},
#  6298220: {'name': 'Ponga',
#   'river': 'Ponga',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298221: {'name': 'Quiroga',
#   'river': 'Bibey',
#   'lat_grid': 42.39166641235352,
#   'lon_grid': -7.2249932289123535,
#   'last_record': '1993-09-15'},
#  6298222: {'name': 'Malpica De Tajo',
#   'river': 'Pusa',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298223: {'name': 'Loeches',
#   'river': 'Pantuerta',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1913-11-15'},
#  6298224: {'name': 'Campillo De Arenas',
#   'river': 'Quiebrajano O Jaen',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298225: {'name': 'Guijo De Granadilla',
#   'river': ' Tajo',
#   'lat_grid': 40.22499847412109,
#   'lon_grid': -6.124992847442627,
#   'last_record': '1986-09-15'},
#  6298226: {'name': 'Huescar',
#   'river': ' Guadalquivir',
#   'lat_grid': 37.85833358764648,
#   'lon_grid': -2.6416594982147217,
#   'last_record': '1967-09-15'},
#  6298227: {'name': 'Cordoba',
#   'river': ' Guadalquivir',
#   'lat_grid': 37.95833206176758,
#   'lon_grid': -4.624992847442627,
#   'last_record': '2013-09-15'},
#  6298228: {'name': 'San Sadurnino',
#   'river': 'Grande De Jubia',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298229: {'name': 'Guesalaz/Gesalatz',
#   'river': 'Salado',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298230: {'name': 'Tirvia',
#   'river': 'Noguera De Cardos',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298231: {'name': 'Almoguera',
#   'river': 'Tajo',
#   'lat_grid': 40.258331298828125,
#   'lon_grid': -2.974992752075196,
#   'last_record': '2013-09-15'},
#  6298232: {'name': 'Tudela',
#   'river': 'Queiles',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298233: {'name': 'Murcia',
#   'river': 'Segura',
#   'lat_grid': 37.97499847412109,
#   'lon_grid': -1.1249927282333374,
#   'last_record': '1951-08-15'},
#  6298234: {'name': 'Calasparra',
#   'river': 'Segura',
#   'lat_grid': 38.258331298828125,
#   'lon_grid': -1.7083261013031006,
#   'last_record': '2013-09-15'},
#  6298235: {'name': 'Corrales De Buelna. Los',
#   'river': 'Besaya',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1993-09-15'},
#  6298236: {'name': 'Calasparra',
#   'river': 'Quipar',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1948-09-15'},
#  6298237: {'name': 'Alcantud',
#   'river': 'Guadiela',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298238: {'name': 'Alcobendas',
#   'river': 'Vega De Arauz',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1985-09-15'},
#  6298239: {'name': 'Ribera De Arriba',
#   'river': 'Nalon',
#   'lat_grid': 43.30833435058594,
#   'lon_grid': -5.908326148986816,
#   'last_record': '2013-09-15'},
#  6298240: {'name': 'Albacete',
#   'river': 'Jucar',
#   'lat_grid': 39.15833282470703,
#   'lon_grid': -1.7083261013031006,
#   'last_record': '2013-09-15'},
#  6298241: {'name': 'Zaidin',
#   'river': 'Clamor Amarga',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298242: {'name': 'Guillena',
#   'river': ' Guadalquivir',
#   'lat_grid': 37.57500076293945,
#   'lon_grid': -6.041659832000732,
#   'last_record': '2013-09-15'},
#  6298243: {'name': 'Aunon',
#   'river': 'Tajo',
#   'lat_grid': 40.49166488647461,
#   'lon_grid': -2.74165940284729,
#   'last_record': '1931-11-15'},
#  6298244: {'name': 'Merida',
#   'river': 'Guadiana',
#   'lat_grid': 38.89166641235352,
#   'lon_grid': -6.474992752075195,
#   'last_record': '1979-01-15'},
#  6298245: {'name': 'Villalba De Los Barros',
#   'river': 'Guadajira',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298246: {'name': 'Puertollano',
#   'river': 'Ojailen',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298247: {'name': 'Laviana',
#   'river': 'Nalon',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298248: {'name': 'Sadaba',
#   'river': 'Arba De Riguel',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298249: {'name': 'Zaragoza',
#   'river': 'Ebro',
#   'lat_grid': 41.65833282470703,
#   'lon_grid': -0.8749926686286926,
#   'last_record': '2013-09-15'},
#  6298250: {'name': 'Castrocontrigo',
#   'river': 'Eria',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298251: {'name': 'Hellin',
#   'river': 'Mundo',
#   'lat_grid': 38.32500076293945,
#   'lon_grid': -1.6583260297775269,
#   'last_record': '2013-08-15'},
#  6298252: {'name': 'Riano',
#   'river': 'Esla',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1974-01-15'},
#  6298253: {'name': 'Llanes',
#   'river': 'Riensena',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2009-09-15'},
#  6298254: {'name': 'Cervera De Pisuerga',
#   'river': 'Rivera',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298255: {'name': 'Lucena',
#   'river': 'Anzur',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2009-09-15'},
#  6298256: {'name': 'Peralejos De Las Truchas',
#   'river': 'Hoz Seca',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298257: {'name': 'Torrebaja',
#   'river': 'Turia O Guadalaviar',
#   'lat_grid': 40.10833358764648,
#   'lon_grid': -1.2583260536193848,
#   'last_record': '2013-09-15'},
#  6298258: {'name': 'Alhambra',
#   'river': 'Azuer',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-04-15'},
#  6298259: {'name': 'Badajoz',
#   'river': 'Guadiana',
#   'lat_grid': 38.85833358764648,
#   'lon_grid': -7.008326530456543,
#   'last_record': '2013-09-15'},
#  6298260: {'name': 'Priego',
#   'river': 'Trabaque',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298261: {'name': 'Boalo. El',
#   'river': 'Navacerrada',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298262: {'name': 'El Valle De Altomira',
#   'river': 'Jabalera',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298263: {'name': 'Argamasilla De Alba',
#   'river': 'Guadiana',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298264: {'name': 'Benuza',
#   'river': 'Cabrera',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1962-09-15'},
#  6298265: {'name': 'Mostoles',
#   'river': 'Guadarrama',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1982-09-15'},
#  6298266: {'name': 'Santisteban Del Puerto',
#   'river': 'Guadalen',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1948-09-15'},
#  6298267: {'name': 'Parrillas',
#   'river': 'Tietar',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298268: {'name': 'Jirueque',
#   'river': 'Henares',
#   'lat_grid': 40.95833206176758,
#   'lon_grid': -2.924992799758911,
#   'last_record': '2013-09-15'},
#  6298269: {'name': 'Badajoz',
#   'river': 'Gevora',
#   'lat_grid': 38.95833206176758,
#   'lon_grid': -6.92499303817749,
#   'last_record': '2012-09-15'},
#  6298270: {'name': 'Alhama De Murcia',
#   'river': ' Segura',
#   'lat_grid': 37.89166641235352,
#   'lon_grid': -1.391659379005432,
#   'last_record': '2013-09-15'},
#  6298271: {'name': 'Salinas De Pisuerga',
#   'river': 'Pisuerga',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298272: {'name': 'Herencia',
#   'river': 'Ciguela',
#   'lat_grid': 39.30833435058594,
#   'lon_grid': -3.358326196670532,
#   'last_record': '2010-10-15'},
#  6298273: {'name': 'Orusco De Tajuna',
#   'river': 'Tajuna',
#   'lat_grid': 40.30833435058594,
#   'lon_grid': -3.191659450531006,
#   'last_record': '2013-09-15'},
#  6298274: {'name': 'Carabantes',
#   'river': 'Caraban',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298275: {'name': 'Carrascal Del Rio',
#   'river': ' Duero',
#   'lat_grid': 41.34166717529297,
#   'lon_grid': -3.8916594982147217,
#   'last_record': '1995-09-15'},
#  6298276: {'name': 'Salvaterra De Mino',
#   'river': 'Tea',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298277: {'name': 'Hoyos Del Espino',
#   'river': 'Tormes',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298278: {'name': 'Penafiel',
#   'river': 'Duraton',
#   'lat_grid': 41.59166717529297,
#   'lon_grid': -4.124992847442627,
#   'last_record': '1995-09-15'},
#  6298279: {'name': 'Domeno',
#   'river': 'Turia O Guadalaviar',
#   'lat_grid': 39.70833206176758,
#   'lon_grid': -0.9416593909263612,
#   'last_record': '1951-09-15'},
#  6298280: {'name': 'Irun',
#   'river': 'Bidasoa',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298281: {'name': 'Valdemorillo',
#   'river': ' Tajo',
#   'lat_grid': 40.54166793823242,
#   'lon_grid': -4.041659355163574,
#   'last_record': '1971-07-15'},
#  6298282: {'name': 'Anguiano',
#   'river': 'Najerilla',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298283: {'name': 'Anchuras',
#   'river': 'Estenilla',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298284: {'name': 'Guadalmez',
#   'river': 'Guadalmez',
#   'lat_grid': 38.72499847412109,
#   'lon_grid': -4.974992752075195,
#   'last_record': '2012-09-15'},
#  6298285: {'name': 'Benageber',
#   'river': 'San Marcos',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1965-09-15'},
#  6298286: {'name': 'Guardo',
#   'river': 'Carrion',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298287: {'name': 'Balaguer',
#   'river': 'Sio',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1992-09-15'},
#  6298288: {'name': 'Helechosa De Los Montes',
#   'river': 'Guadiana',
#   'lat_grid': 39.35833358764648,
#   'lon_grid': -4.92499303817749,
#   'last_record': '1931-11-15'},
#  6298289: {'name': 'Santa Maria Del Val',
#   'river': 'Cuervo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298290: {'name': 'Villabanez',
#   'river': 'Jaramiel',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1992-09-15'},
#  6298291: {'name': 'Pobra Do Brollon. A',
#   'river': 'Cabe',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1952-09-15'},
#  6298292: {'name': 'San Pedro Manrique',
#   'river': 'Linares',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2009-09-15'},
#  6298293: {'name': 'Bugarra',
#   'river': 'Turia O Guadalaviar',
#   'lat_grid': 39.60833358764648,
#   'lon_grid': -0.7749927043914795,
#   'last_record': '2013-09-15'},
#  6298294: {'name': 'Torrejon El Rubio',
#   'river': ' Tajo',
#   'lat_grid': 39.84166717529297,
#   'lon_grid': -5.991659641265869,
#   'last_record': '1986-09-15'},
#  6298295: {'name': 'Hernan-Perez',
#   'river': 'Tralgas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298296: {'name': 'Ponferrada',
#   'river': 'Sil',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298297: {'name': 'Cordoba',
#   'river': 'Guadalquivir',
#   'lat_grid': 37.82500076293945,
#   'lon_grid': -4.8416595458984375,
#   'last_record': '1924-11-15'},
#  6298298: {'name': 'Polan',
#   'river': 'Tajo',
#   'lat_grid': 39.82500076293945,
#   'lon_grid': -4.291659355163574,
#   'last_record': '1931-11-15'},
#  6298299: {'name': 'Oviedo',
#   'river': 'Nalon',
#   'lat_grid': 43.45833206176758,
#   'lon_grid': -6.0916595458984375,
#   'last_record': '1918-07-15'},
#  6298300: {'name': 'Pedroso. El',
#   'river': 'Huesna',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298301: {'name': 'Valdesamario',
#   'river': 'Omanas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1994-02-15'},
#  6298302: {'name': 'Tosos',
#   'river': 'Huerva',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298303: {'name': 'Toro',
#   'river': 'Guarena',
#   'lat_grid': 41.47499847412109,
#   'lon_grid': -5.391659736633301,
#   'last_record': '2013-09-15'},
#  6298304: {'name': 'Marmolejo',
#   'river': 'Yeguas O Pradillo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2006-07-15'},
#  6298305: {'name': 'Gavarda',
#   'river': 'Jucar',
#   'lat_grid': 39.09166717529297,
#   'lon_grid': -0.558326005935669,
#   'last_record': '1961-09-15'},
#  6298306: {'name': 'Hornachuelos',
#   'river': 'Bembezar',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2009-09-15'},
#  6298307: {'name': 'Getafe',
#   'river': 'Culebro',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2000-09-15'},
#  6298308: {'name': 'Silleda',
#   'river': 'Deza',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298309: {'name': 'Bernardos',
#   'river': 'Eresma',
#   'lat_grid': 41.15833282470703,
#   'lon_grid': -4.3416595458984375,
#   'last_record': '2013-09-15'},
#  6298310: {'name': 'Biescas',
#   'river': 'Gallego',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298311: {'name': 'Alcora. L',
#   'river': ' Jucar',
#   'lat_grid': 40.02499771118164,
#   'lon_grid': -0.1583259850740432,
#   'last_record': '1946-09-15'},
#  6298312: {'name': 'Fonfria',
#   'river': 'Duero',
#   'lat_grid': 41.57500076293945,
#   'lon_grid': -6.191659450531006,
#   'last_record': '1995-09-15'},
#  6298313: {'name': 'Robledo. El',
#   'river': 'Bullaque',
#   'lat_grid': 39.20833206176758,
#   'lon_grid': -4.291659355163574,
#   'last_record': '1918-05-15'},
#  6298314: {'name': 'Argamasilla De Alba',
#   'river': ' Guadiana',
#   'lat_grid': 39.05833435058594,
#   'lon_grid': -3.0083260536193848,
#   'last_record': '1922-12-15'},
#  6298315: {'name': 'Benejuzar',
#   'river': 'Segura',
#   'lat_grid': 38.07500076293945,
#   'lon_grid': -0.8583260178565979,
#   'last_record': '2013-09-15'},
#  6298316: {'name': 'Aroche',
#   'river': 'Chanza',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1960-09-15'},
#  6298317: {'name': 'Belmonte De Miranda',
#   'river': 'Piguena',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298318: {'name': 'Rivas-Vaciamadrid',
#   'river': 'Jarama',
#   'lat_grid': 40.39166641235352,
#   'lon_grid': -3.5083260536193848,
#   'last_record': '2013-09-15'},
#  6298319: {'name': 'Morata De Jiloca',
#   'river': 'Jiloca',
#   'lat_grid': 41.258331298828125,
#   'lon_grid': -1.591659426689148,
#   'last_record': '2013-09-15'},
#  6298320: {'name': 'Lorca',
#   'river': ' Segura',
#   'lat_grid': 37.74166488647461,
#   'lon_grid': -1.8249927759170528,
#   'last_record': '2013-09-15'},
#  6298321: {'name': 'Vinuesa',
#   'river': ' Duero',
#   'lat_grid': 41.875,
#   'lon_grid': -2.7083261013031006,
#   'last_record': '2013-09-15'},
#  6298322: {'name': 'Embid De Ariza',
#   'river': 'Deza',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298323: {'name': 'Galisteo',
#   'river': 'Alagon',
#   'lat_grid': 39.97499847412109,
#   'lon_grid': -6.308326244354248,
#   'last_record': '2013-09-15'},
#  6298324: {'name': 'Ponferrada',
#   'river': 'Sil',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1959-09-15'},
#  6298325: {'name': 'Quintanilla De Onesimo',
#   'river': 'Duero',
#   'lat_grid': 41.625,
#   'lon_grid': -4.358326435089111,
#   'last_record': '2013-09-15'},
#  6298326: {'name': 'Baeza',
#   'river': ' Guadalquivir',
#   'lat_grid': 37.90833282470703,
#   'lon_grid': -3.4083261489868164,
#   'last_record': '1995-09-15'},
#  6298327: {'name': 'Cervera Del Rio Alhama',
#   'river': 'Alhama',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298328: {'name': 'Graus',
#   'river': 'Esera',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298329: {'name': 'Cullera',
#   'river': 'Jucar',
#   'lat_grid': 39.17499923706055,
#   'lon_grid': -0.2749926745891571,
#   'last_record': '1996-09-15'},
#  6298330: {'name': 'Hellin',
#   'river': ' Segura',
#   'lat_grid': 38.35833358764648,
#   'lon_grid': -1.7749927043914795,
#   'last_record': '2013-09-15'},
#  6298331: {'name': 'Cazalegas',
#   'river': ' Tajo',
#   'lat_grid': 40.008331298828125,
# ...
#   'river': 'Avia',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298871: {'name': 'Santa Colomba De Curueno',
#   'river': 'Curueno',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298872: {'name': 'Talavera La Real',
#   'river': 'Entrin',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298873: {'name': 'Pajaroncillo',
#   'river': 'Cabriel',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298874: {'name': 'Nuevalos',
#   'river': 'Piedra',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298875: {'name': 'Yeste',
#   'river': ' Segura',
#   'lat_grid': 38.39166641235352,
#   'lon_grid': -2.2083261013031006,
#   'last_record': '1949-09-15'},
#  6298876: {'name': 'Izalzu/Itzaltzu',
#   'river': 'Anduna',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298877: {'name': 'Madrid',
#   'river': 'Manzanares',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298878: {'name': 'Morcin',
#   'river': 'Caudal',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298879: {'name': 'Castro De Rei',
#   'river': 'Mino',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298880: {'name': 'Cintruenigo',
#   'river': 'Alhama',
#   'lat_grid': 42.07500076293945,
#   'lon_grid': -1.8083261251449585,
#   'last_record': '2013-09-15'},
#  6298881: {'name': 'Robleda',
#   'river': 'Agueda',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1992-09-15'},
#  6298882: {'name': 'Penamellera Baja',
#   'river': 'Deva',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298883: {'name': 'Mengabril',
#   'river': 'Ortigas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298884: {'name': 'Canamero',
#   'river': 'Ruecas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298885: {'name': 'Ribera De Arriba',
#   'river': 'Nalon',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1930-09-15'},
#  6298886: {'name': 'Castuera',
#   'river': 'Zujar',
#   'lat_grid': 38.92499923706055,
#   'lon_grid': -5.474992752075195,
#   'last_record': '1978-09-15'},
#  6298887: {'name': 'Lobon',
#   'river': 'Guadajira',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298888: {'name': 'Losar De La Vera',
#   'river': 'Cuartos',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298889: {'name': 'Zafra',
#   'river': 'Guadajira',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1976-09-15'},
#  6298890: {'name': 'Alange',
#   'river': 'Valdemedel',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298891: {'name': 'Isaba/Izaba',
#   'river': 'Esca',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298892: {'name': 'Soutomaior',
#   'river': 'Oitaven',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1987-09-15'},
#  6298893: {'name': 'Nerpio',
#   'river': ' Segura',
#   'lat_grid': 38.19166564941406,
#   'lon_grid': -2.2583260536193848,
#   'last_record': '2005-04-15'},
#  6298894: {'name': 'Ribera D Urgellet',
#   'river': 'Vansa',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1980-09-15'},
#  6298895: {'name': 'Beniarres',
#   'river': ' Jucar',
#   'lat_grid': 38.80833435058594,
#   'lon_grid': -0.3583259880542755,
#   'last_record': '1931-11-15'},
#  6298896: {'name': 'Jabalquinto',
#   'river': 'Guadiel',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298897: {'name': 'Medina De Pomar',
#   'river': 'Trueba',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298898: {'name': 'Cardenosa',
#   'river': ' Duero',
#   'lat_grid': 40.72499847412109,
#   'lon_grid': -4.691659450531006,
#   'last_record': '2013-09-15'},
#  6298899: {'name': 'Guijo De Granadilla',
#   'river': 'Ambroz',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298900: {'name': 'Montanuy',
#   'river': 'Baliera',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1997-09-15'},
#  6298901: {'name': 'Hornachuelos',
#   'river': 'Bembezar',
#   'lat_grid': 37.82500076293945,
#   'lon_grid': -5.241659641265869,
#   'last_record': '1947-09-15'},
#  6298902: {'name': 'Monreal De Ariza',
#   'river': 'Najima',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298903: {'name': 'Trujillo',
#   'river': 'Tozo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298904: {'name': 'Cervera De Pisuerga',
#   'river': 'Pisuerga',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298905: {'name': 'Mutxamel',
#   'river': 'Monegre',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1945-09-15'},
#  6298906: {'name': 'Riego De La Vega',
#   'river': 'Tuerto',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298907: {'name': 'Calasparra',
#   'river': 'Segura',
#   'lat_grid': 38.258331298828125,
#   'lon_grid': -1.7083261013031006,
#   'last_record': '1986-09-15'},
#  6298908: {'name': 'Canal De Berdun',
#   'river': 'Veral',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298909: {'name': 'Seu D Urgell. La',
#   'river': 'Segre',
#   'lat_grid': 42.35833358764648,
#   'lon_grid': 1.458340764045715,
#   'last_record': '2013-09-15'},
#  6298910: {'name': 'Puente La Reina De Jaca',
#   'river': 'Subordan',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298911: {'name': 'Castillejo De Martin Viejo',
#   'river': 'Agueda',
#   'lat_grid': 40.69166564941406,
#   'lon_grid': -6.658326148986816,
#   'last_record': '2008-09-15'},
#  6298912: {'name': 'Blesa',
#   'river': 'Aguas Vivas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2009-09-15'},
#  6298913: {'name': 'Orihuela',
#   'river': 'Segura',
#   'lat_grid': 38.07500076293945,
#   'lon_grid': -0.9583260416984558,
#   'last_record': '1993-09-15'},
#  6298914: {'name': 'Villamanin',
#   'river': ' Duero',
#   'lat_grid': 42.92499923706055,
#   'lon_grid': -5.758326053619385,
#   'last_record': '2013-09-15'},
#  6298915: {'name': 'Badajoz',
#   'river': 'Alcazaba',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298916: {'name': 'Villarmayor',
#   'river': 'Tormes',
#   'lat_grid': 41.07500076293945,
#   'lon_grid': -5.941659450531006,
#   'last_record': '2008-09-15'},
#  6298917: {'name': 'Fayos. Los',
#   'river': 'Val',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1997-10-15'},
#  6298918: {'name': 'Guitiriz',
#   'river': 'Parga',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298919: {'name': 'Medina De Rioseco',
#   'river': 'Sequillo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298920: {'name': 'Alcaudete De La Jara',
#   'river': 'Gebalo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298921: {'name': 'Pedrezuela',
#   'river': ' Tajo',
#   'lat_grid': 40.758331298828125,
#   'lon_grid': -3.624992847442627,
#   'last_record': '1986-09-15'},
#  6298922: {'name': 'Aroche',
#   'river': 'Chanza',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2005-11-15'},
#  6298923: {'name': 'Cremenes',
#   'river': 'Esla',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298924: {'name': 'Hellin',
#   'river': ' Segura',
#   'lat_grid': 38.34166717529297,
#   'lon_grid': -1.641659379005432,
#   'last_record': '1957-09-15'},
#  6298925: {'name': 'Iguena',
#   'river': 'Tremor',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298926: {'name': 'Lezuza',
#   'river': 'Lezuza',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298927: {'name': 'Villanueva Del Rio Y Minas',
#   'river': 'Parroso',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298928: {'name': 'Cordobilla De Lacara',
#   'river': 'Lacara',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298929: {'name': 'Pontes De Garcia Rodriguez. As',
#   'river': 'Eume',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298930: {'name': 'Fayos. Los',
#   'river': 'Queiles',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298931: {'name': 'Valdesotos',
#   'river': ' Tajo',
#   'lat_grid': 41.008331298828125,
#   'lon_grid': -3.308326244354248,
#   'last_record': '1986-09-15'},
#  6298932: {'name': 'Villanueva Del Rio Y Minas',
#   'river': 'Galapagar',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2009-09-15'},
#  6298933: {'name': 'Alarcon',
#   'river': 'Jucar',
#   'lat_grid': 39.55833435058594,
#   'lon_grid': -2.108326196670532,
#   'last_record': '2013-09-15'},
#  6298934: {'name': 'Brime De Urz',
#   'river': 'Almucera',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298935: {'name': 'Caceres',
#   'river': 'Tamuja',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298936: {'name': 'Mula',
#   'river': ' Segura',
#   'lat_grid': 38.05833435058594,
#   'lon_grid': -1.49165940284729,
#   'last_record': '2013-09-15'},
#  6298937: {'name': 'Beneixida',
#   'river': 'Jucar',
#   'lat_grid': 39.07500076293945,
#   'lon_grid': -0.5416593551635742,
#   'last_record': '1948-09-15'},
#  6298938: {'name': 'Hellin',
#   'river': 'Mundo',
#   'lat_grid': 38.34166717529297,
#   'lon_grid': -1.6583260297775269,
#   'last_record': '1960-11-15'},
#  6298939: {'name': 'Pilona',
#   'river': 'Pilona',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298940: {'name': 'Galisteo',
#   'river': 'Jerte',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298941: {'name': 'Lorca',
#   'river': 'Luchena',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1931-11-15'},
#  6298942: {'name': 'Puente De Domingo Florez',
#   'river': 'Cabrera',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-05-15'},
#  6298943: {'name': 'Fiscal',
#   'river': 'Ara',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1971-09-15'},
#  6298944: {'name': 'Fabara',
#   'river': 'Matarrana',
#   'lat_grid': 41.19166564941406,
#   'lon_grid': 0.1750073581933975,
#   'last_record': '2013-09-15'},
#  6298945: {'name': 'Montoro',
#   'river': ' Guadalquivir',
#   'lat_grid': 38.07500076293945,
#   'lon_grid': -4.258326053619385,
#   'last_record': '2013-09-15'},
#  6298946: {'name': 'Moneva',
#   'river': 'Moyuela',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1971-09-15'},
#  6298947: {'name': 'San Tirso De Abres',
#   'river': 'Eo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298948: {'name': 'Llavorsi',
#   'river': 'Santa Magdalena',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1982-10-15'},
#  6298949: {'name': 'Aranjuez',
#   'river': 'Tajo',
#   'lat_grid': 40.04166793823242,
#   'lon_grid': -3.558326244354248,
#   'last_record': '2013-09-15'},
#  6298950: {'name': 'Villafranca De Los Caballeros',
#   'river': 'Ciguela',
#   'lat_grid': 39.508331298828125,
#   'lon_grid': -3.308326244354248,
#   'last_record': '2012-09-15'},
#  6298951: {'name': 'Cordoba',
#   'river': 'Guadalquivir',
#   'lat_grid': 37.82500076293945,
#   'lon_grid': -4.891659736633301,
#   'last_record': '1929-11-15'},
#  6298952: {'name': 'Berantevilla',
#   'river': 'Ayuda',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298953: {'name': 'Cerda',
#   'river': 'Canoles',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1953-09-15'},
#  6298954: {'name': 'Miranda De Ebro',
#   'river': 'Zadorra',
#   'lat_grid': 42.67499923706055,
#   'lon_grid': -2.8916594982147217,
#   'last_record': '2013-09-15'},
#  6298955: {'name': 'Calasparra',
#   'river': 'Segura',
#   'lat_grid': 38.29166412353516,
#   'lon_grid': -1.691659450531006,
#   'last_record': '2013-09-15'},
#  6298956: {'name': 'Quiroga',
#   'river': 'Lor',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298957: {'name': 'Huerto',
#   'river': 'Guatizalema',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298958: {'name': 'Pobla De Segur. La',
#   'river': 'Flamisell',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1992-09-15'},
#  6298959: {'name': 'Santa Amalia',
#   'river': 'Burdalo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298960: {'name': 'Posada De Valdeon',
#   'river': 'Cares',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1962-09-15'},
#  6298961: {'name': 'Mansilla De Las Mulas',
#   'river': 'Esla',
#   'lat_grid': 42.508331298828125,
#   'lon_grid': -5.374992847442627,
#   'last_record': '2013-09-15'},
#  6298962: {'name': 'Omanas. Las',
#   'river': 'Omanas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298963: {'name': 'Andujar',
#   'river': 'Jandula O Fresneda',
#   'lat_grid': 38.35833358764648,
#   'lon_grid': -3.941659450531006,
#   'last_record': '1931-11-15'},
#  6298964: {'name': 'Ribeira De Piquin',
#   'river': 'Eo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298965: {'name': 'Talayuela',
#   'river': 'Santamaria',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1992-09-15'},
#  6298966: {'name': 'Molinaseca',
#   'river': 'Meruelo',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1961-09-15'},
#  6298967: {'name': 'Ciempozuelos',
#   'river': 'Jarama',
#   'lat_grid': 40.14166641235352,
#   'lon_grid': -3.5749928951263428,
#   'last_record': '2013-09-15'},
#  6298968: {'name': 'Bohonal De Ibor',
#   'river': 'Ibor',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298969: {'name': 'Outeiro De Rei',
#   'river': 'Narla',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298970: {'name': 'Valdovino',
#   'river': 'Rego Das Mestas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298971: {'name': 'Chinchon',
#   'river': 'Tajuna',
#   'lat_grid': 40.14166641235352,
#   'lon_grid': -3.5416595935821533,
#   'last_record': '1931-11-15'},
#  6298972: {'name': 'Daimiel',
#   'river': 'Guadiana',
#   'lat_grid': 39.125,
#   'lon_grid': -3.608326196670532,
#   'last_record': '1931-11-15'},
#  6298973: {'name': 'Humada',
#   'river': 'Odra',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '1987-09-15'},
#  6298974: {'name': 'Campanario',
#   'river': 'Guadalefra',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  6298975: {'name': 'Sumacarcer',
#   'river': 'Jucar',
#   'lat_grid': 39.125,
#   'lon_grid': -0.6416593194007874,
#   'last_record': '2013-09-15'},
#  6298976: {'name': 'Peraleda De San Roman',
#   'river': 'Gualija',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298977: {'name': 'Sevilla',
#   'river': 'Guadalquivir',
#   'lat_grid': 37.35833358764648,
#   'lon_grid': -6.024992942810059,
#   'last_record': '1965-09-15'},
#  6298978: {'name': 'Valverde Del Fresno',
#   'river': 'Trevejana',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298979: {'name': 'Torreblascopedro',
#   'river': 'Guadalimar',
#   'lat_grid': 38.008331298828125,
#   'lon_grid': -3.6416594982147217,
#   'last_record': '2012-09-15'},
#  6298980: {'name': 'Horta De Sant Joan',
#   'river': 'Algas',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298981: {'name': 'Mendavia',
#   'river': 'Ebro',
#   'lat_grid': 42.40833282470703,
#   'lon_grid': -2.2083261013031006,
#   'last_record': '2013-09-15'},
#  6298982: {'name': 'Mequinenza',
#   'river': 'Ebro',
#   'lat_grid': 41.35833358764648,
#   'lon_grid': 0.2916740477085113,
#   'last_record': '1968-09-15'},
#  6298983: {'name': 'Toreno',
#   'river': 'Sil',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-01-15'},
#  6298984: {'name': 'Villarejo De Montalban',
#   'river': 'Cedena',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298985: {'name': 'Palma Del Rio',
#   'river': 'Guadalquivir',
#   'lat_grid': 37.70833206176758,
#   'lon_grid': -5.308326244354248,
#   'last_record': '1914-09-15'},
#  6298986: {'name': 'Guntin',
#   'river': 'Ferreira',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2013-09-15'},
#  6298987: {'name': 'Badajoz',
#   'river': 'Rivilla',
#   'lat_grid': nan,
#   'lon_grid': nan,
#   'last_record': '2012-09-15'},
#  ...}

# %%
# plot station location on a map with rivers and coastlines
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cartopy.feature.RIVERS)
ax.set_extent([-10, 6, 35, 45])
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
for key, coordinates in stations_merit_csv.items():
    if ((coordinates['river'] == 'Guadiana')):
        plt.scatter(coordinates['lon_grid'], coordinates['lat_grid'], s=30, label=coordinates['name'], marker='o')
plt.title('Location of selected stations')
plt.legend()
# Out:
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(
# /home/ptiengou/.conda/envs/lam1env/lib/python3.12/site-packages/pyproj/transformer.py:820: UserWarning: Warning: converting a masked element to nan.
#   return self._transformer._transform_point(

# %%
# remove years not between 2003 and 2012
# stations = stations.where((stations['time.year'] >= 2003), drop=True)
# stations = stations.where((stations['time.year'] <= 2012), drop=True)

# %%
#plot time series of mergedhydro for a selected station
station_id = 6299001
mask = (stations['number'] == station_id)
station = stations.sel(stations=mask)
station = station.where((stations['time.year'] >= 1981), drop=True)
plt.figure(figsize=(15, 5))
plt.plot(station['time'], station['mergedhydro'], label='GRDC')
#print dict row for the selected station
print (str(station_id) + ':' + str(stations_merit_csv[station_id]) + ',')
# Out:
# 6299001:{'name': 'Ciudad Real', 'river': ' Guadiana', 'lat_grid': 39.05833435058594, 'lon_grid': -3.991659641265869, 'last_record': '2002-02-15'},

# %%
# create a dict with id name, lon lat for a subset of stations
stations_merit = {
    6298249: {'name': 'Zaragoza',  'river': 'Ebro', 'lon_grid':-0.8749926686286926, 'lat_grid':41.65833282470703, 'year_min':1982, 'year_max':2010},
    6298992: {'name': 'Albarreal De Tajo',  'river': 'Tajo', 'lon_grid':-4.17499303817749, 'lat_grid':39.891666412353516, 'year_min':1982, 'year_max':2010 },
    6298481: {'name': 'San Miguel del Pino', 'river': 'Duero', 'lon_grid':-4.92499303817749, 'lat_grid':41.508331298828125, 'year_min':1982, 'year_max':2010},
    6298259:{'name': 'Badajoz', 'river': 'Guadiana', 'lat_grid': 38.85833358764648, 'lon_grid': -7.008326530456543, 'last_record': '2013-09-15', 'year_min':1996, 'year_max':2010},
    # 6298564: {'name': 'Villanueva de Azoague', 'lon_grid':-5.641659736633301, 'lat_grid':41.974998474121094, 'year_min':1982, 'year_max':2012},
    # 6299121:{'name': 'Orellana La Vieja', 'river': ' Guadiana', 'lat_grid': 38.99166488647461, 'lon_grid': -5.541659832000732, 'last_record': '2013-09-15'},
    # 6298071:{'name': 'Constantina', 'river': ' Guadalquivir', 'lat_grid': 37.77499771118164, 'lon_grid': -5.691659450531006, 'last_record': '2013-09-15', 'year_min':1994, 'year_max':2009},
    # 6299029:{'name': 'Santiago-Pontones', 'river': ' Guadalquivir', 'lat_grid': 38.17499923706055, 'lon_grid': -2.791659355163574, 'last_record': '2013-09-15'},
    # # 6298149:{'name': 'Lucena', 'river': ' Guadalquivir', 'lat_grid': 37.29166412353516, 'lon_grid': -4.67499303817749, 'last_record': '2009-04-15'},
    # # 6298597:{'name': 'Guejar Sierra', 'river': ' Guadalquivir', 'lat_grid': 37.15833282470703, 'lon_grid': -3.474992752075196, 'last_record': '2012-09-15'},
    # 6298606:{'name': 'Pozo Alcon', 'river': ' Guadalquivir', 'lat_grid': 37.758331298828125, 'lon_grid': -2.9083261489868164, 'last_record': '2013-09-15'},
    # # 6298731:{'name': 'Valdepenas De Jaen', 'river': ' Guadalquivir', 'lat_grid': 37.625, 'lon_grid': -3.7249927520751953, 'last_record': '2013-09-15'},
    # 6299108:{'name': 'Hornachuelos', 'river': ' Guadalquivir', 'lat_grid': 37.90833282470703, 'lon_grid': -5.20832633972168, 'last_record': '2013-09-15'},
    # 6299220:{'name': 'Villacarrillo', 'river': ' Guadalquivir', 'lat_grid': 38.04166412353516, 'lon_grid': -2.9583261013031006, 'last_record': '2013-09-15'},
}

# %%
# plot station location on a map with rivers and coastlines
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cartopy.feature.RIVERS)
ax.set_extent([-10, 4, 35, 45])
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
gl.ylocator = gl.ylocator = plt.MaxNLocator(5)
gl.right_labels = False
gl.top_labels = False
for key, coordinates in stations_merit.items():
    plt.scatter(coordinates['lon_grid'], coordinates['lat_grid'], s=30, label=coordinates['name'], marker='o')
plt.title('Location of selected station')
#activate legend and put it in the bottom right corner
plt.legend(loc='lower right')

# %%
# visualize time series for selected stations
fig, ax = plt.subplots(2, 2, figsize=(25, 10))
ax = ax.flatten()
for i, (key, coordinates) in enumerate(stations_merit.items()):
    mask = (stations['number'] == key)
    station = stations.sel(stations=mask)
    #remove years before 2003 and after 2012
    station = station.where((station['time.year'] >= coordinates['year_min']), drop=True)
    station = station.where((station['time.year'] <= coordinates['year_max']), drop=True)
    ax[i].plot(station['time'],station['mergedhydro'], label='obs', c='black')
    ax[i].set_title(coordinates['name'])
    ax[i].set_ylabel('discharge [m3/s]')
    ax[i].legend()

# %%
# visualize seasonnal cycle for selected stations
fig, ax = plt.subplots(2, 2, figsize=(20, 10))
for i, (key, coordinates) in enumerate(stations_merit.items()):
    mask = (stations['number'] == key)
    station = stations.sel(stations=mask)
    ax = ax.flatten()
    #remove years before 2003 and after 2012
    station = station.where((station['time.year'] >= coordinates['year_min']), drop=True)
    station = station.where((station['time.year'] <= coordinates['year_max']), drop=True)
    station = station.groupby('time.month').mean()
    ax[i].set_title(coordinates['name'])
    ax[i].plot(station['month'],station['mergedhydro'], label='obs', c='black')
    ax[i].set_ylabel('discharge [m3/s]')
    #set Y minimum to 0
    ax[i].set_ylim(bottom=0)
    #add months name to x-axis ticks
    months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    ax[i].set_xticks(np.arange(1,13))
    ax[i].set_xticklabels(months)
    ax[i].legend()
plt.tight_layout()

# %% [markdown]
# # Seasonnal cycles

# %%
# seasonnal cycle for one station
station_id=6298249
mask = (stations['number'] == station_id)
station = stations.sel(stations=mask)
ds1=natDIAG_R
ds2=natDIAG_Rirr
# ds3=natDIAG_Rirr06
lon = stations_merit[station_id]['lon_grid']
lat = stations_merit[station_id]['lat_grid']
name = stations_merit[station_id]['name']
# year_min = stations_merit[station_id]['year_min']
# year_max = stations_merit[station_id]['year_max']
year_min = 2010
year_max = 2013
min_date='{}-01-01'.format(year_min)
max_date='{}-12-31'.format(year_max)
river=stations_merit[station_id]['river']

plt.figure(figsize=(22, 13))

var1=ds1['hydrographs'].sel(time=slice(min_date, max_date))
var2=ds2['hydrographs'].sel(time=slice(min_date, max_date))
# var3=ds3['hydrographs'].sel(time=slice(min_date, max_date))
var1.sel(lon=lon, lat=lat, method='nearest').groupby('time.month').mean(dim='time').plot(label=ds1.attrs['name'])
var2.sel(lon=lon, lat=lat, method='nearest').groupby('time.month').mean(dim='time').plot(label=ds2.attrs['name'])
# var3.sel(lon=lon, lat=lat, method='nearest').groupby('time.month').mean(dim='time').plot(label=ds3.attrs['name'])

station = station.where((station['time.year'] >= year_min), drop=True)
station = station.where((station['time.year'] <= year_max), drop=True)
station = station.groupby('time.month').mean()
plt.plot(station['month'],station['mergedhydro'], label='obs', c='black')

plt.ylim(bottom=0)
# plt.ylim(top=400)
months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
plt.xticks(np.arange(1,13), labels=months)
# plt.ticks(labels=months)
plt.xlabel('')
plt.ylabel('')
plt.legend(loc='upper right')
plt.title('Mean seasonnal cycle for station {}, on {} ({}-{})'.format(name, river, year_min, year_max))
# Out:
# Text(0.5, 1.0, 'Mean seasonnal cycle for station Zaragoza, on Ebro (2010-2013)')

# %%
#cycle saisonnier pour x points de grille
ds1 = natDIAG_R
ds2 = natDIAG_Rirr
# ds3 = natDIAG_RGSWP3
# ds4 = natDIAG_RGSWP3irr
# ds3 = natDIAG_Rirr06

# Create subplots for each river in a 2x3 grid
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate over rivers and plot hydrographs
for i, (sta_id, coordinates) in enumerate(stations_merit.items()):
    lon = coordinates['lon_grid']
    lat = coordinates['lat_grid']
    name = coordinates['name']
    # year_min = coordinates['year_min']
    # year_max = coordinates['year_max']
    year_min=2010
    year_max=2013
    river=coordinates['river']
    min_date='{}-01-01'.format(year_min)
    max_date='{}-12-31'.format(year_max)
    
    ax = axes[i]

    #Compute the annual cycle of hydrographs at the point (lon, lat) for each dataset
    var1=ds1['hydrographs'].sel(time=slice(min_date, max_date))
    var2=ds2['hydrographs'].sel(time=slice(min_date, max_date))
    # var3=ds3['hydrographs'].sel(time=slice(min_date, max_date))
    # var4=ds4['hydrographs'].sel(time=slice(min_date, max_date))
    var1.sel(lon=lon, lat=lat, method='nearest').groupby('time.month').mean(dim='time').plot(ax=ax, label=ds1.attrs['name'])
    var2.sel(lon=lon, lat=lat, method='nearest').groupby('time.month').mean(dim='time').plot(ax=ax, label=ds2.attrs['name'])
    # var3.sel(lon=lon, lat=lat, method='nearest').groupby('time.month').mean(dim='time').plot(ax=ax, label=ds3.attrs['name'])
    # var4.sel(lon=lon, lat=lat, method='nearest').groupby('time.month').mean(dim='time').plot(ax=ax, label=ds4.attrs['name'])
    
    # Compute the annual cycle of hydrographs at the point (lon, lat) for observation
    mask = (stations['number'] == sta_id)
    station = stations.sel(stations=mask)
    station = station.where((station['time.year'] >= year_min), drop=True)
    station = station.where((station['time.year'] <= year_max), drop=True)
    station=station.groupby('time.month').mean()
    ax.plot(station['month'],station['mergedhydro'], label='obs', c='black')
    
    #add months name to x-axis ticks
    months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    ax.set_xticks(np.arange(1,13))
    ax.set_xticklabels(months)
    ax.set_ylabel('')
    ax.set_xlabel('')
    if (i==0):
        ax.legend(loc='lower left')
    ax.set_title('Station {}, on {} ({}-{})'.format(name, river, year_min, year_max))

# Remove any remaining empty subplots
for i in range(len(stations_merit), len(axes)):
    fig.delaxes(axes[i])

plt.suptitle("Seasonal cycle of river discharge (m³/s)")
plt.tight_layout()

# %% [markdown]
# # Time series

# %%
#Série temporelle pour x points de grille
ds1 = natDIAG_R
ds2 = natDIAG_Rirr
# ds3 = natDIAG_RGSWP3
# ds4 = natDIAG_RGSWP3irr

# Create subplots for each river in a 2x3 grid
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate over rivers and plot hydrographs
for i, (sta_id, coordinates) in enumerate(stations_merit.items()):
    lon = coordinates['lon_grid']
    lat = coordinates['lat_grid']
    name = coordinates['name']
    # year_min = coordinates['year_min']
    # year_max = coordinates['year_max']
    year_min=2010
    year_max=2013
    river=coordinates['river']
    min_date='{}-01-01'.format(year_min)
    max_date='{}-12-31'.format(year_max)
    
    ax = axes[i]

    #Compute the annual cycle of hydrographs at the point (lon, lat) for each dataset
    var1=ds1['hydrographs'].sel(time=slice(min_date, max_date))
    var2=ds2['hydrographs'].sel(time=slice(min_date, max_date))
    # var3=ds3['hydrographs'].sel(time=slice(min_date, max_date))
    # var4=ds4['hydrographs'].sel(time=slice(min_date, max_date))
    var1.sel(lon=lon, lat=lat, method='nearest').plot(ax=ax, label=ds1.attrs['name'])
    var2.sel(lon=lon, lat=lat, method='nearest').plot(ax=ax, label=ds2.attrs['name'])
    # var3.sel(lon=lon, lat=lat, method='nearest').plot(ax=ax, label=ds3.attrs['name'])
    # var4.sel(lon=lon, lat=lat, method='nearest').plot(ax=ax, label=ds4.attrs['name'])
    
    # Compute the annual cycle of hydrographs at the point (lon, lat) for observation
    mask = (stations['number'] == sta_id)
    station = stations.sel(stations=mask)
    station = station.where((station['time.year'] >= year_min), drop=True)
    station = station.where((station['time.year'] <= year_max), drop=True)
    ax.plot(station['time'],station['mergedhydro'], label='obs', c='black')
    
    ax.set_ylabel('')
    ax.set_xlabel('')
    ax.legend()
    ax.set_title('Station {}, on {} ({}-{})'.format(name, river, year_min, year_max))

plt.suptitle("River discharge (m³/s)")
plt.tight_layout()

# %%
#Average time series
var='hydrographs'
ds1=natDIAG_Rirr
fig = plt.figure(figsize=(10, 6))
ax = plt.axes()
ax.grid()
ds1[var].mean(dim=['lon','lat']).plot(ax=ax, label=ds1.name)
plt.title(var)
plt.legend()

# %%
#Time series
year_min=2003
year_max=2012
# # Guadalquivir
lon=-6.34
lat=36.79

var="hydrographs"
ds1=std
ds1 = ds1.where(ds1['time.year'] >= year_min, drop=True).where(ds1['time.year'] <= year_max, drop=True)
ds2=natDIAG_R
ds2 = ds2.where(ds2['time.year'] >= year_min, drop=True).where(ds2['time.year'] <= year_max, drop=True)
#plot the time series of hydrographs at the point (lon,lat)
fig = plt.figure(figsize=(10, 6))
ax = plt.axes()
ax.grid()
ax.set_ylabel('hydrographs')
# ds1[var].sel(lon=lon, lat=lat, method='nearest').plot(ax=ax, label=ds1.name)
ds2[var].sel(lon=lon, lat=lat, method='nearest').plot(ax=ax, label=ds2.name)
# ds2['runoff'].sel(lon=lon, lat=lat, method='nearest').plot(ax=ax, label='runoff')
plt.title('hydrographs at (' + str(lon) + ',' + str(lat) + '), m³/s')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 9
#       6 lat=36.79
#       8 var="hydrographs"
# ----> 9 ds1=std
#      10 ds1 = ds1.where(ds1['time.year'] >= year_min, drop=True).where(ds1['time.year'] <= year_max, drop=True)
#      11 ds2=natDIAG_R
#
# NameError: name 'std' is not defined

# %%
#Time series
year_min=2003
year_max=2012
lon=-8.875
lat=41.86
ds1=natDIAG_R
ds1 = ds1.where(ds1['time.year'] >= year_min, drop=True).where(ds1['time.year'] <= year_max, drop=True)
#plot the time series of hydrographs at the point (lon,lat)
fig = plt.figure(figsize=(10, 6))
ax = plt.axes()
ax.grid()
ds1['runoff'].sel(lon=lon, lat=lat, method='nearest').plot(ax=ax, label='runoff',c='green')
ds1['drainage'].sel(lon=lon, lat=lat, method='nearest').plot(ax=ax, label='drainage',c='brown')
# ['rain'].sel(lon=lon, lat=lat, method='nearest').plot(ax=ax, label='rainfall',c='blue')
plt.title('Runoff and drainage at (' + str(lon) + ',' + str(lat) + '), mm/d')
plt.legend()
